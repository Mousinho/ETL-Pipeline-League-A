# %%
# %sql
CREATE DATABASE IF NOT EXISTS futdata

# %%
# %sql
USE futdata

# %%
# %sql
show databases

# %%
# %sql
SELECT current_database()

# %%
# %run "../Modulo 3//00_config_storage"

# %%
from pyspark.sql.functions import col

matches_df = spark.read.parquet("abfss://gold@datalakebricksxperiun.dfs.core.windows.net/fact_matches")

matches_df = df.withColumn("league_season", col("league_season").cast("string"))

display(matches_df)

# %%
df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("futdata.ft_matches")

# %%
# %sql
SHOW TABLES IN futdata;

# %%
# %sql
DESC futdata.ft_matches

# %%
# %sql
SELECT * FROM futdata.ft_matches WHERE referee = "Raphael Claus"
