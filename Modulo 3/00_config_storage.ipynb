# %%
#
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope="escopo-senha-xp")

# %%
SENHA_APP = dbutils.secrets.get("escopo-senha-xp", "senha-app-segredo")
id_client = dbutils.secrets.get("escopo-senha-xp", "idCliente")
id_locatario = dbutils.secrets.get("escopo-senha-xp", "idLocatario")

# %%
id_cliente = id_client
id_locatario = id_locatario

# %%
senha_app = SENHA_APP

# %%
spark.conf.set("fs.azure.account.auth.type.datalakebricksxperiun.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.datalakebricksxperiun.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.datalakebricksxperiun.dfs.core.windows.net", id_cliente)
spark.conf.set("fs.azure.account.oauth2.client.secret.datalakebricksxperiun.dfs.core.windows.net", senha_app)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.datalakebricksxperiun.dfs.core.windows.net", "https://login.windows.net/d86259b4-b815-47f6-b8da-1f32864a9182/oauth2/token")

# %%
configs = {"fs.azure.account.auth.type": "OAuth",

           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",

           "fs.azure.account.oauth2.client.id": id_cliente,

           "fs.azure.account.oauth2.client.secret": senha_app,

           "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{id_locatario}/oauth2/token"}
