# %%
# %run "../Modulo 3/00_config_storage/"

# %%
# %run "../Modulo 4/Variables/"

# %%
file_name = "torneios"
path = f"{path_silver}/{file_name}"

# %%
championship_df = spark.read.parquet(path)

# %%
display(championship_df)

# %%
file_name = "partidas"
path = f"{path_silver}/{file_name}"

# %%
match_df = spark.read.parquet(path)

# %%
display(match_df)

# %%
championship_df_serie_A = championship_df.filter(championship_df.league_id == "71")
display(championship_df_serie_A)

# %%
#championship_df_serie_A = championship_df.filter(
#    (championship_df.league_id == "71") & (championship_df.season_current == "True"))
championship_df_serie_A = championship_df.filter(
    "league_id = 71 AND season_current = 'True'"
)

display(championship_df_serie_A)
