# %%
path_bronze = "abfss://bronze@datalakebricksxperiun.dfs.core.windows.net/"
path_silver = "abfss://silver@datalakebricksxperiun.dfs.core.windows.net/"
path_gold = "abfss://gold@datalakebricksxperiun.dfs.core.windows.net/"

# %%
print("Imported Variables")
